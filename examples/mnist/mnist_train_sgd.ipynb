# %%
import os

if not os.path.exists("STAGE"):
    # !git clone https://github.com/TaikiiNomura/STAGE

# %cd STAGE
# !pip install -e .
# Out:
# Cloning into 'STAGE'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 81 (delta 12), reused 72 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 13.81 KiB | 2.76 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/STAGE
# Obtaining file:///content/STAGE
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for stage (pyproject.toml) ... done
#   Created wheel for stage: filename=stage-0.1.0-0.editable-py3-none-any.whl size=2669 sha256=2bdb1a02ee59c5f2f5e40f18f0c24fc98d793aa5186310f9c0b6995b1ecb4e9d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bienw874/wheels/b9/2c/3d/063bd85756ee715ec79a28236cf457378a7f2a44d03f37aa98
# Successfully built stage
# ...

# %%
# !python examples/mnist/mnist_sgd.py --epochs 20 --verbose
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.282551
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.682900
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.615529
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.523529
# Test set: Average loss: 0.3178, Accuracy: 9089/10000 (90.89%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.634303
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.296413
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.514777
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.423945
# Test set: Average loss: 0.2392, Accuracy: 9325/10000 (93.25%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.258043
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 0.395769
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.212278
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 0.290815
# Test set: Average loss: 0.2027, Accuracy: 9393/10000 (93.93%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.465246
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 0.238896
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.252280
# ...
