# %%
import os

if not os.path.exists("STAGE"):
    # !git clone https://github.com/TaikiiNomura/STAGE

# %cd STAGE
# !pip install -e .
# Out:
# Cloning into 'STAGE'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 96 (delta 20), reused 71 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (96/96), 17.32 KiB | 8.66 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/STAGE
# Obtaining file:///content/STAGE
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for stage (pyproject.toml) ... done
#   Created wheel for stage: filename=stage-0.1.0-0.editable-py3-none-any.whl size=2669 sha256=4230d07e21dc779a807ecd0f987cbc5d66ce1c9c994ce693cbf068f826130b98
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0_vjc41l/wheels/b9/2c/3d/063bd85756ee715ec79a28236cf457378a7f2a44d03f37aa98
# Successfully built stage
# ...

# %%
# !python examples/quadratic/quadratic_compare.py --step 20 --lr 1.0 --tau 0.1 --eps 1e-2
# Out:
# === SGD ===
# Step   0  x 10.000000  loss 49.000000  grad 14.000000
# Step   1  x -4.000000  loss 49.000000  grad -14.000000
# Step   2  x 10.000000  loss 49.000000  grad 14.000000
# Step   3  x -4.000000  loss 49.000000  grad -14.000000
# Step   4  x 10.000000  loss 49.000000  grad 14.000000
# Step   5  x -4.000000  loss 49.000000  grad -14.000000
# Step   6  x 10.000000  loss 49.000000  grad 14.000000
# Step   7  x -4.000000  loss 49.000000  grad -14.000000
# Step   8  x 10.000000  loss 49.000000  grad 14.000000
# Step   9  x -4.000000  loss 49.000000  grad -14.000000
# Step  10  x 10.000000  loss 49.000000  grad 14.000000
# Step  11  x -4.000000  loss 49.000000  grad -14.000000
# Step  12  x 10.000000  loss 49.000000  grad 14.000000
# Step  13  x -4.000000  loss 49.000000  grad -14.000000
# Step  14  x 10.000000  loss 49.000000  grad 14.000000
# Step  15  x -4.000000  loss 49.000000  grad -14.000000
# Step  16  x 10.000000  loss 49.000000  grad 14.000000
# ...
