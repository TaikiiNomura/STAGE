# %%
import os

if not os.path.exists("STAGE"):
    # !git clone https://github.com/TaikiiNomura/STAGE

# %cd STAGE
# !pip install -e .
# Out:
# Cloning into 'STAGE'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 101 (delta 23), reused 71 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (101/101), 18.32 KiB | 468.00 KiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /content/STAGE
# Obtaining file:///content/STAGE
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for stage (pyproject.toml) ... done
#   Created wheel for stage: filename=stage-0.1.0-0.editable-py3-none-any.whl size=2669 sha256=44396b022e062d454c2085c20ccad0fda501e5aa411415936a54970dccc11b16
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ldj6ju25/wheels/b9/2c/3d/063bd85756ee715ec79a28236cf457378a7f2a44d03f37aa98
# Successfully built stage
# ...

# %%
# !python examples/sin/sin_sgd.py \
--verbose \
--epochs 10000 \
--hidden 128 \
--tau 0.01
# Out:
# Epoch 0 Loss 44.550421
# Epoch 200 Loss 0.163191
# Epoch 400 Loss 0.143573
# Epoch 600 Loss 0.139665
# Epoch 800 Loss 0.138140
# Epoch 1000 Loss 0.137031
# Epoch 1200 Loss 0.136047
# Epoch 1400 Loss 0.135081
# Epoch 1600 Loss 0.134098
# Epoch 1800 Loss 0.133066
# Epoch 2000 Loss 0.131964
# Epoch 2200 Loss 0.130771
# Epoch 2400 Loss 0.129476
# Epoch 2600 Loss 0.128083
# Epoch 2800 Loss 0.126590
# Epoch 3000 Loss 0.124987
# Epoch 3200 Loss 0.123270
# Epoch 3400 Loss 0.121434
# Epoch 3600 Loss 0.119476
# Epoch 3800 Loss 0.117391
# Epoch 4000 Loss 0.115172
# Epoch 4200 Loss 0.112820
# Epoch 4400 Loss 0.110343
# Epoch 4600 Loss 0.107739
# Epoch 4800 Loss 0.105014
# Epoch 5000 Loss 0.102177
# Epoch 5200 Loss 0.099225
# Epoch 5400 Loss 0.096173
# Epoch 5600 Loss 0.093039
# Epoch 5800 Loss 0.089829
# Epoch 6000 Loss 0.086548
# Epoch 6200 Loss 0.083211
# Epoch 6400 Loss 0.079847
# Epoch 6600 Loss 0.076475
# Epoch 6800 Loss 0.073090
# Epoch 7000 Loss 0.069703
# Epoch 7200 Loss 0.066353
# ...
